# %% [markdown]
# ## Combine Datasets

# %%
import pandas as pd

# Combine all district CSVs into one master dataset
df = pd.concat([
    pd.read_csv('../../datasets/updated_coordinates/district1.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district2.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district3.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district4.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district5.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district6.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district7.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district8.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district9.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district10.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district11.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district12.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district13.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district14.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district15.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district16.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district17.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district18.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district19.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district20.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district21.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district22.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district23.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district25.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district26.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district27.csv'),
    pd.read_csv('../../datasets/updated_coordinates/district28.csv')
], ignore_index=True)

df.drop_duplicates(inplace=True)
df.to_csv('../../datasets/updated_coordinates/combined_updated.csv', index=False)

# %%
df
# Out:
#                  Project Name Transacted Price ($) Area (SQFT)  \
# 0          ONE MARINA GARDENS            1,883,403       656.6
# 1          ONE MARINA GARDENS            2,055,683       656.6
# 2       MARINA BAY RESIDENCES            1,755,000      731.95
# 3          ONE MARINA GARDENS            2,038,262      667.37
# 4       MARINA ONE RESIDENCES            4,260,000    2,249.68
# ...                       ...                  ...         ...
# 107106            THE ESTUARY              901,000       925.7
# 107107        YISHUN SAPPHIRE            1,050,000    1,388.56
# 107108  NORTH PARK RESIDENCES            1,070,000      753.48
# 107109       KANDIS RESIDENCE              975,800      796.54
# 107110       KANDIS RESIDENCE            1,019,000      731.95
#
#        Unit Price ($ PSF) Sale Date          Street Name Type of Sale  \
# 0                   2,868    Sep-25  MARINA GARDENS LANE     New Sale
# 1                   3,131    Sep-25  MARINA GARDENS LANE     New Sale
# 2                   2,398    Sep-25     MARINA BOULEVARD       Resale
# 3                   3,054    Sep-25  MARINA GARDENS LANE     New Sale
# 4                   1,894    Sep-25           MARINA WAY       Resale
# ...                   ...       ...                  ...          ...
# 107106                973    Sep-20      YISHUN AVENUE 1       Resale
# 107107                756    Sep-20       CANBERRA DRIVE       Resale
# 107108              1,420    Sep-20     YISHUN CENTRAL 1     Sub Sale
# 107109              1,225    Sep-20          KANDIS LINK     New Sale
# 107110              1,392    Sep-20          KANDIS LINK     New Sale
#
#        Type of Area Area (SQM) Unit Price ($ PSM)  ...  Latitude   Longitude  \
# 0            Strata       61.0             30,875  ...  1.275801  103.862936
# 1            Strata       61.0             33,700  ...  1.275801  103.862936
# 2            Strata       68.0             25,809  ...  1.279626  103.854987
# 3            Strata       62.0             32,875  ...  1.275801  103.862936
# 4            Strata      209.0             20,383  ...  1.277224  103.853695
# ...             ...        ...                ...  ...       ...         ...
# 107106       Strata       86.0             10,477  ...  1.410900  103.832147
# 107107       Strata      129.0              8,140  ...  1.440184  103.830572
# 107108       Strata       70.0             15,286  ...  1.427400  103.835693
# 107109       Strata       74.0             13,186  ...  1.456436  103.837219
# 107110       Strata       68.0             14,985  ...  1.456436  103.837219
#
#                                              Full Address  \
# 0       3 MARINA GARDENS LANE ONE MARINA GARDENS (U/C)...
# 1       3 MARINA GARDENS LANE ONE MARINA GARDENS (U/C)...
# 2       18 MARINA BOULEVARD MARINA BAY RESIDENCES SING...
# 3       3 MARINA GARDENS LANE ONE MARINA GARDENS (U/C)...
# 4       23 MARINA WAY MARINA ONE RESIDENCES SINGAPORE ...
# ...                                                   ...
# 107106    97 YISHUN AVENUE 1 THE ESTUARY SINGAPORE 769138
# 107107  48 CANBERRA DRIVE YISHUN SAPPHIRE SINGAPORE 76...
# 107108  21 YISHUN CENTRAL 1 NORTH PARK RESIDENCES SING...
# 107109    2 KANDIS LINK KANDIS RESIDENCE SINGAPORE 756967
# 107110    2 KANDIS LINK KANDIS RESIDENCE SINGAPORE 756967
#
#                                      Nearest MRT Stations  \
# 0       MARINA SOUTH MRT STATION; MARINA SOUTH PIER MR...
# 1       MARINA SOUTH MRT STATION; MARINA SOUTH PIER MR...
# 2       DOWNTOWN MRT STATION; MARINA BAY MRT STATION; ...
# 3       MARINA SOUTH MRT STATION; MARINA SOUTH PIER MR...
# 4       MARINA BAY MRT STATION; MARINA BAY MRT STATION...
# ...                                                   ...
# 107106                                 KHATIB MRT STATION
# 107107                               CANBERRA MRT STATION
# 107108                                 YISHUN MRT STATION
# 107109                                                NaN
# 107110                                                NaN
#
#                                     Nearby Hawker Centers  \
# 0                                                     NaN
# 1                                                     NaN
# 2       Amoy Street Food Centre (Telok Ayer Food Centr...
# 3                                                     NaN
# 4       Amoy Street Food Centre (Telok Ayer Food Centr...
# ...                                                   ...
# 107106                                                NaN
# 107107  Yishun Ring Road Blk 104/105 (Chong Pang Marke...
# 107108  Chong Pang Hawker Centre & Market; Yishun Ring...
# 107109                                                NaN
# 107110                                                NaN
#
#                       Shopping Malls Within Radius of 1km  \
# 0                                                     NaN
# 1                                                     NaN
# 2       Marina Bay Sands; The Shoppes at Marina Bay Sa...
# 3                                                     NaN
# 4       The Shoppes at Marina Bay Sands; Marina Bay Li...
# ...                                                   ...
# 107106                                                NaN
# 107107          Canberra Plaza; Sembawang Shopping Centre
# 107108                     Junction Nine; Northpoint City
# 107109                                                NaN
# 107110                                                NaN
#
#                            Hospitals Within Radius of 5km  \
# 0       Changi General Hospital; KK Women's and Childr...
# 1       Changi General Hospital; KK Women's and Childr...
# 2       Changi General Hospital; KK Women's and Childr...
# 3       Changi General Hospital; KK Women's and Childr...
# 4       Changi General Hospital; KK Women's and Childr...
# ...                                                   ...
# 107106  Khoo Teck Puat Hospital; Woodlands Health Camp...
# 107107  Khoo Teck Puat Hospital; Woodlands Health Camp...
# 107108  Khoo Teck Puat Hospital; Woodlands Health Camp...
# 107109  Khoo Teck Puat Hospital; Yishun Community Hosp...
# 107110  Khoo Teck Puat Hospital; Yishun Community Hosp...
#
#                              Schools Within Radius of 2km  \
# 0                                                     NaN
# 1                                                     NaN
# 2               CANTONMENT PRIMARY SCHOOL; TAO NAN SCHOOL
# 3                                                     NaN
# 4               CANTONMENT PRIMARY SCHOOL; TAO NAN SCHOOL
# ...                                                   ...
# 107106  CHUNG CHENG HIGH SCHOOL (YISHUN); JIEMIN PRIMA...
# 107107  AHMAD IBRAHIM PRIMARY SCHOOL; AHMAD IBRAHIM SE...
# 107108  AHMAD IBRAHIM PRIMARY SCHOOL; AHMAD IBRAHIM SE...
# 107109                          WELLINGTON PRIMARY SCHOOL
# 107110                          WELLINGTON PRIMARY SCHOOL
#
#                                Parks Within Radius of 1km Dist to CBD in Km
# 0                                                     NaN          1.548671
# 1                                                     NaN          1.548671
# 2       MARKET STREET PARK; EMPRESS PLACE; RAFFLES PLA...          0.579753
# 3                                                     NaN          1.548671
# 4       MARKET STREET PARK; RAFFLES PLACE PK; TELOK AY...          0.705572
# ...                                                   ...               ...
# 107106                       LOWER SELETAR RESERVOIR PARK         14.297299
# 107107  YISHUN NEIGHBOURHOOD PK; KEMUNING PK; LEGUNDI ...         17.528668
# 107108                          YISHUN PK; YISHUN POND PK         16.057647
# 107109  SEMBAWANG PK; KANDIS GARDEN; JANGGUS GARDEN; I...         19.238928
# 107110  SEMBAWANG PK; KANDIS GARDEN; JANGGUS GARDEN; I...         19.238928
#
# [103133 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Project Name', 'Transacted Price ($)', 'Area (SQFT)',
#        'Unit Price ($ PSF)', 'Sale Date', 'Street Name', 'Type of Sale',
#        'Type of Area', 'Area (SQM)', 'Unit Price ($ PSM)', 'Nett Price($)',
#        'Property Type', 'Number of Units', 'Tenure', 'Postal District',
#        'Market Segment', 'Floor Level', 'Latitude', 'Longitude',
#        'Full Address', 'Nearest MRT Stations', 'Nearby Hawker Centers',
#        'Shopping Malls Within Radius of 1km', 'Hospitals Within Radius of 5km',
#        'Schools Within Radius of 2km', 'Parks Within Radius of 1km',
#        'Dist to CBD in Km'],
#       dtype='object')

# %% [markdown]
# ## Import ML Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
def count_items(x):
    if pd.isna(x):
        return 0
    return len(str(x).split(";"))

df["num_mrt"] = df["Nearest MRT Stations"].apply(count_items)
df["num_hawkers"] = df["Nearby Hawker Centers"].apply(count_items)
df["num_malls"] = df["Shopping Malls Within Radius of 1km"].apply(count_items)
df["num_hospitals"] = df["Hospitals Within Radius of 5km"].apply(count_items)
df["num_schools"] = df["Schools Within Radius of 2km"].apply(count_items)
df["num_parks"] = df["Parks Within Radius of 1km"].apply(count_items)
df["dist_cbd"] = df["Dist to CBD in Km"]

# %%
df["Transacted Price ($)"] = (
    df["Transacted Price ($)"]
    .astype(str)
    .str.replace(",", "")
    .astype(float)
)

# %%
weights = {
    "young": {
        "dist_cbd": 0.2376,
        "num_mrt": 0.1338,
        "num_hawkers": 0.1019,
        "num_malls": 0.1353,
        "num_hospitals": 0.0792,
        "num_schools": 0.2080,
        "num_parks": 0.0983
    },
    "families": {
        "dist_cbd": 0.0709,
        "num_mrt": 0.1819,
        "num_hawkers": 0.1149,
        "num_malls": 0.2932,
        "num_hospitals": 0.1699,
        "num_schools": 0.0867,
        "num_parks": 0.0826
    },
    "retirees": {
        "dist_cbd": 0.0420,
        "num_mrt": 0.1658,
        "num_hawkers": 0.2665,
        "num_malls": 0.0969,
        "num_hospitals": 0.1971,
        "num_schools": 0.0569,
        "num_parks": 0.1748
    }
}

# %%
df.columns
# Out:
# Index(['Project Name', 'Transacted Price ($)', 'Area (SQFT)',
#        'Unit Price ($ PSF)', 'Sale Date', 'Street Name', 'Type of Sale',
#        'Type of Area', 'Area (SQM)', 'Unit Price ($ PSM)', 'Nett Price($)',
#        'Property Type', 'Number of Units', 'Tenure', 'Postal District',
#        'Market Segment', 'Floor Level', 'Latitude', 'Longitude',
#        'Full Address', 'Nearest MRT Stations', 'Nearby Hawker Centers',
#        'Shopping Malls Within Radius of 1km', 'Hospitals Within Radius of 5km',
#        'Schools Within Radius of 2km', 'Parks Within Radius of 1km',
#        'Dist to CBD in Km', 'num_mrt', 'num_hawkers', 'num_malls',
#        'num_hospitals', 'num_schools', 'num_parks', 'dist_cbd'],
#       dtype='object')

# %%
# clean_property_score_by_age.py
import os
import numpy as np
import pandas as pd

# ---------------- CONFIG ----------------
INPUT_CSV = "../../datasets/updated_coordinates/combined_updated.csv"
OUTPUT_DIR = "../../datasets/updated_coordinates/outputs/"
TOP_N = 10
# ----------------------------------------

AGE_WEIGHTS = {
    'young': {
        'dist_to_cbd': 0.2376,
        'Num_MRT_With_1km': 0.1338,
        'Num_Hawker_Within_1km': 0.1019,
        'Num_Malls_Within_1km': 0.1353,
        'Num_Hospitals_Within_5km': 0.0792,
        'Num_Schools_Within_2km': 0.2080,
        'Num_Parks_Within_1km': 0.0983
    },
    'family': {
        'dist_to_cbd': 0.0709,
        'Num_MRT_With_1km': 0.1819,
        'Num_Hawker_Within_1km': 0.1149,
        'Num_Malls_Within_1km': 0.2932,
        'Num_Hospitals_Within_5km': 0.1699,
        'Num_Schools_Within_2km': 0.0867,
        'Num_Parks_Within_1km': 0.0826
    },
    'retiree': {
        'dist_to_cbd': 0.0420,
        'Num_MRT_With_1km': 0.1658,
        'Num_Hawker_Within_1km': 0.2665,
        'Num_Malls_Within_1km': 0.0969,
        'Num_Hospitals_Within_5km': 0.1971,
        'Num_Schools_Within_2km': 0.0569,
        'Num_Parks_Within_1km': 0.1748
    }
}

def ensure_dir(path):
    os.makedirs(path, exist_ok=True)

def count_semicolon_separated(x):
    """Count items in semicolon-separated string."""
    if pd.isna(x):
        return 0
    s = str(x).strip()
    if not s:
        return 0
    try:
        return max(0, int(float(s)))
    except ValueError:
        pass
    parts = [p.strip() for p in s.replace(',', ';').split(';') if p.strip()]
    return len(parts)

def robust_minmax_norm(series):
    """Min-max normalize with robust handling."""
    s = pd.to_numeric(series, errors='coerce')
    vmin, vmax = s.min(skipna=True), s.max(skipna=True)
    
    if pd.isna(vmin) or pd.isna(vmax) or vmax == vmin:
        return pd.Series(0.0, index=s.index)
    
    normalized = (s - vmin) / (vmax - vmin)
    return normalized.fillna(0.0).clip(0.0, 1.0)

def find_column(df, candidates):
    """Find first matching column from candidates."""
    for col in candidates:
        if col in df.columns:
            return col
    return None

def prepare_and_score(input_csv, output_dir, top_n=10):
    ensure_dir(output_dir)
    
    if not os.path.exists(input_csv):
        raise FileNotFoundError(f"Input CSV not found: {input_csv}")
    
    df = pd.read_csv(input_csv)
    df = df.drop_duplicates().reset_index(drop=True)
    print(f"✓ Loaded {len(df):,} rows from {input_csv}")
    
    # ========== EXTRACT AMENITY COUNTS ==========
    amenity_mappings = {
        'Num_MRT_With_1km': [
            'Nearest MRT Stations', 'Nearest_MRT_Stations', 
            'Num MRT Within 1km', 'Num_MRT_With_1km'
        ],
        'Num_Hawker_Within_1km': [
            'Nearby Hawker Centers', 'Nearby_Hawker_Centers',
            'Num Hawker Within 1km', 'Num_Hawker_Within_1km'
        ],
        'Num_Malls_Within_1km': [
            'Shopping Malls Within Radius of 1km', 'Shopping Malls Within 1km',
            'Num Malls Within 1km', 'Num_Malls_Within_1km'
        ],
        'Num_Hospitals_Within_5km': [
            'Hospitals Within Radius of 5km', 'Hospitals Within 5km',
            'Num Hospitals Within 5km', 'Num_Hospitals_Within_5km'
        ],
        'Num_Schools_Within_2km': [
            'Schools Within Radius of 2km', 'Schools Within 2km',
            'Num Schools Within 2km', 'Num_Schools_Within_2km'
        ],
        'Num_Parks_Within_1km': [
            'Parks Within Radius of 1km', 'Parks Within 1km',
            'Num Parks Within 1km', 'Num_Parks_Within_1km'
        ]
    }
    
    for target_col, candidates in amenity_mappings.items():
        source_col = find_column(df, candidates)
        if source_col:
            if pd.api.types.is_numeric_dtype(df[source_col]):
                df[target_col] = pd.to_numeric(df[source_col], errors='coerce').fillna(0).astype(int)
            else:
                df[target_col] = df[source_col].apply(count_semicolon_separated)
        else:
            df[target_col] = 0
            print(f"⚠ Warning: No source found for {target_col}, using 0")
    
    # ========== DISTANCE TO CBD ==========
    dist_candidates = ['Dist to CBD in Km', 'Dist to CBD (Km)', 'Dist_to_CBD_km', 'dist_to_cbd']
    dist_col = find_column(df, dist_candidates)
    if dist_col:
        df['dist_to_cbd'] = pd.to_numeric(df[dist_col], errors='coerce')
    else:
        df['dist_to_cbd'] = np.nan
        print("⚠ Warning: No distance to CBD column found")
    
    # ========== POSTAL DISTRICT (if available) ==========
    if 'Postal District' in df.columns:
        df['Postal District'] = df['Postal District'].astype(str)
    else:
        df['Postal District'] = ''
    
    # ========== AREA ==========
    if 'Area (SQM)' not in df.columns and 'Area (SQFT)' in df.columns:
        df['Area (SQM)'] = pd.to_numeric(df['Area (SQFT)'], errors='coerce') * 0.092903
    elif 'Area (SQM)' not in df.columns:
        df['Area (SQM)'] = np.nan
    
    # ========== UNIT PRICE PSM (FIXED) ==========
    if 'Unit Price ($ PSM)' in df.columns:
        # Clean the existing Unit Price ($ PSM) column if it's string-formatted
        if pd.api.types.is_numeric_dtype(df['Unit Price ($ PSM)']):
            df['unit_price_psm'] = pd.to_numeric(df['Unit Price ($ PSM)'], errors='coerce')
        else:
            # Remove commas and convert to numeric
            price_psm_clean = df['Unit Price ($ PSM)'].astype(str).str.replace(',', '').str.replace('$', '').str.strip()
            df['unit_price_psm'] = pd.to_numeric(price_psm_clean, errors='coerce')
    elif 'Unit Price ($ PSF)' in df.columns:
        if pd.api.types.is_numeric_dtype(df['Unit Price ($ PSF)']):
            df['unit_price_psm'] = pd.to_numeric(df['Unit Price ($ PSF)'], errors='coerce') * 10.7639
        else:
            price_psf_clean = df['Unit Price ($ PSF)'].astype(str).str.replace(',', '').str.replace('$', '').str.strip()
            df['unit_price_psm'] = pd.to_numeric(price_psf_clean, errors='coerce') * 10.7639
    else:
        # Fallback: calculate from Transacted Price / Area
        price_candidates = ['Transacted Price ($)', 'Transacted Price', 'Price ($)', 'Price']
        price_col = find_column(df, price_candidates)
        
        if price_col is not None:
            price_clean = df[price_col].astype(str).str.replace(',', '').str.replace('$', '').str.strip()
            price_clean = pd.to_numeric(price_clean, errors='coerce')
            
            area_clean = pd.to_numeric(df['Area (SQM)'], errors='coerce')
            
            df['unit_price_psm'] = price_clean / area_clean.replace(0, np.nan)
        else:
            df['unit_price_psm'] = np.nan
            print("⚠ Warning: No price column found for unit_price_psm calculation")

    df['unit_price_psm'] = df['unit_price_psm'].replace([np.inf, -np.inf], np.nan)

    # Debug: Check if unit_price_psm has valid values
    valid_prices = df['unit_price_psm'].notna().sum()
    print(f"✓ Valid unit_price_psm values: {valid_prices:,} / {len(df):,}")
    
    # ========== NORMALIZE FEATURES ==========
    print("\n✓ Normalizing features...")
    
    amenity_cols = [
        'Num_MRT_With_1km', 'Num_Hawker_Within_1km', 'Num_Malls_Within_1km',
        'Num_Hospitals_Within_5km', 'Num_Schools_Within_2km', 'Num_Parks_Within_1km'
    ]
    
    for col in amenity_cols:
        df[f'{col}_norm'] = robust_minmax_norm(df[col])
    
    # Distance: closer is better (convert to proximity)
    df['dist_to_cbd_norm'] = robust_minmax_norm(df['dist_to_cbd'])
    df['dist_proximity_norm'] = 1.0 - df['dist_to_cbd_norm']
    
    # Affordability: lower price is better (inverse normalized)
    # Only normalize if we have valid prices
    if df['unit_price_psm'].notna().sum() > 0:
        df['affordability_norm'] = robust_minmax_norm(df['unit_price_psm'])
        df['affordability_norm'] = 1.0 - df['affordability_norm']
    else:
        # If no price data, set affordability to 0.5 (neutral) instead of 0
        df['affordability_norm'] = 0.5
        print("⚠ Warning: No valid unit prices found, setting affordability_norm to 0.5")
    
    # ========== COMPUTE SCORES ==========
    print("\n✓ Computing age-group scores...")
    
    feature_to_norm_col = {
        'dist_to_cbd': 'dist_proximity_norm',
        'Num_MRT_With_1km': 'Num_MRT_With_1km_norm',
        'Num_Hawker_Within_1km': 'Num_Hawker_Within_1km_norm',
        'Num_Malls_Within_1km': 'Num_Malls_Within_1km_norm',
        'Num_Hospitals_Within_5km': 'Num_Hospitals_Within_5km_norm',
        'Num_Schools_Within_2km': 'Num_Schools_Within_2km_norm',
        'Num_Parks_Within_1km': 'Num_Parks_Within_1km_norm'
    }
    
    for age_group, weights in AGE_WEIGHTS.items():
        amenity_score = np.zeros(len(df))
        
        for feature, weight in weights.items():
            norm_col = feature_to_norm_col.get(feature)
            if norm_col and norm_col in df.columns:
                amenity_score += weight * df[norm_col].values
        
        df[f'score_property_{age_group}'] = amenity_score
        df[f'worth_{age_group}'] = amenity_score * df['affordability_norm']
    
    # ========== DATA QUALITY FLAGS ==========
    df['has_all_amenities'] = (
        (df['Num_MRT_With_1km'] + df['Num_Hawker_Within_1km'] + 
         df['Num_Malls_Within_1km'] + df['Num_Hospitals_Within_5km'] + 
         df['Num_Schools_Within_2km'] + df['Num_Parks_Within_1km']) > 0
    ).astype(int)
    
    df['has_price_data'] = df['unit_price_psm'].notna().astype(int)
    
    # ========== SAVE RESULTS ==========
    combined_out = os.path.join(output_dir, "combined_property_scores.csv")
    df.to_csv(combined_out, index=False)
    print(f"\nSaved combined property-level CSV: {combined_out}")
    
    # ========== SAVE TOP N PER AGE GROUP ==========
    for age_group in AGE_WEIGHTS.keys():
        display_cols = [
            'Project Name', 'Postal District', 'Transacted Price ($)', 'Area (SQM)', 'unit_price_psm',
            'dist_to_cbd', 'dist_proximity_norm', f'score_property_{age_group}', 
            'affordability_norm', f'worth_{age_group}'
        ]
        display_cols = [c for c in display_cols if c in df.columns]
        
        # Filter valid properties
        valid_df = df[df['has_all_amenities'] == 1].copy()
        
        # Get top N by worth
        top_df = valid_df.nlargest(top_n, f'worth_{age_group}')[display_cols]
        
        out_file = os.path.join(output_dir, f"top{top_n}_{age_group}.csv")
        top_df.to_csv(out_file, index=False)
        
        print(f"\nTop {top_n} properties for '{age_group}' saved to: {out_file}")
        print(top_df.to_string(index=False))
    
    return df

# ========== EXECUTE ==========
if __name__ == "__main__":
    df_result = prepare_and_score(INPUT_CSV, OUTPUT_DIR, top_n=TOP_N)
# Out:
# /var/folders/g_/fmz6fbfx0l96hfjsv2764ypw0000gn/T/ipykernel_81142/3934505332.py:83: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_csv)
# ✓ Loaded 103,133 rows from ../../datasets/updated_coordinates/combined_updated.csv
# ✓ Valid unit_price_psm values: 103,133 / 103,133
#
# ✓ Normalizing features...
#
# ✓ Computing age-group scores...
#
# Saved combined property-level CSV: ../../datasets/updated_coordinates/outputs/combined_property_scores.csv
#
# Top 10 properties for 'young' saved to: ../../datasets/updated_coordinates/outputs/top10_young.csv
#          Project Name Postal District Transacted Price ($) Area (SQM)  unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_young  affordability_norm  worth_young
# PEOPLE'S PARK COMPLEX             1.0              700,000      104.0            6731      0.95205             0.964691              0.648601            0.944409     0.612545
# PEOPLE'S PARK COMPLEX             1.0            1,138,000      149.0            7638      0.95205             0.964691              0.648601            0.931073     0.603895
# PEOPLE'S PARK COMPLEX             1.0            1,148,000      149.0            7705      0.95205             0.964691              0.648601            0.930088     0.603256
# PEOPLE'S PARK COMPLEX             1.0              900,688      104.0            8660      0.95205             0.964691              0.648601            0.916047     0.594149
# PEOPLE'S PARK COMPLEX             1.0              920,000      104.0            8846      0.95205             0.964691              0.648601            0.913312     0.592375
# PEOPLE'S PARK COMPLEX             1.0            1,350,000      149.0            9060      0.95205             0.964691              0.648601            0.910166     0.590335
# PEOPLE'S PARK COMPLEX             1.0              950,888      104.0            9143      0.95205             0.964691              0.648601            0.908945     0.589543
# PEOPLE'S PARK COMPLEX             1.0              965,000      104.0            9279      0.95205             0.964691              0.648601            0.906946     0.588246
# PEOPLE'S PARK COMPLEX             1.0              988,000      104.0            9500      0.95205             0.964691              0.648601            0.903696     0.586139
# PEOPLE'S PARK COMPLEX             1.0            1,050,000      109.0            9633      0.95205             0.964691              0.648601            0.901741     0.584870
#
# Top 10 properties for 'family' saved to: ../../datasets/updated_coordinates/outputs/top10_family.csv
#          Project Name Postal District Transacted Price ($) Area (SQM)  unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_family  affordability_norm  worth_family
#         WATERLOO VIEW             7.0            1,600,000        165            9697     1.973531             0.912326               0.681452            0.900800      0.613852
#         HONG BUILDING             8.0            1,422,850      127.0           11204     1.795329             0.921461               0.692715            0.878643      0.608649
#         WATERLOO VIEW             7.0            1,820,000        165           11030     1.973531             0.912326               0.681452            0.881201      0.600496
# PEOPLE'S PARK COMPLEX             1.0              700,000      104.0            6731     0.952050             0.964691               0.605874            0.944409      0.572192
#        SUNSHINE PLAZA             7.0            1,448,800        121           11974     1.918217             0.915161               0.651859            0.867321      0.565371
# PEOPLE'S PARK COMPLEX             1.0            1,138,000      149.0            7638     0.952050             0.964691               0.605874            0.931073      0.564113
# PEOPLE'S PARK COMPLEX             1.0            1,148,000      149.0            7705     0.952050             0.964691               0.605874            0.930088      0.563516
#        SUNSHINE PLAZA             7.0            1,550,000        125           12400     1.918217             0.915161               0.651859            0.861058      0.561288
#        SUNSHINE PLAZA             7.0            1,970,000        156           12628     1.918217             0.915161               0.651859            0.857706      0.559103
# PEOPLE'S PARK COMPLEX             1.0              900,688      104.0            8660     0.952050             0.964691               0.605874            0.916047      0.555009
#
# Top 10 properties for 'retiree' saved to: ../../datasets/updated_coordinates/outputs/top10_retiree.csv
#          Project Name Postal District Transacted Price ($) Area (SQM)  unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_retiree  affordability_norm  worth_retiree
# PEOPLE'S PARK COMPLEX             1.0              700,000      104.0            6731      0.95205             0.964691                0.757353            0.944409       0.715251
# PEOPLE'S PARK COMPLEX             1.0            1,138,000      149.0            7638      0.95205             0.964691                0.757353            0.931073       0.705151
# PEOPLE'S PARK COMPLEX             1.0            1,148,000      149.0            7705      0.95205             0.964691                0.757353            0.930088       0.704405
# PEOPLE'S PARK COMPLEX             1.0              900,688      104.0            8660      0.95205             0.964691                0.757353            0.916047       0.693771
# PEOPLE'S PARK COMPLEX             1.0              920,000      104.0            8846      0.95205             0.964691                0.757353            0.913312       0.691700
# PEOPLE'S PARK COMPLEX             1.0            1,350,000      149.0            9060      0.95205             0.964691                0.757353            0.910166       0.689317
# PEOPLE'S PARK COMPLEX             1.0              950,888      104.0            9143      0.95205             0.964691                0.757353            0.908945       0.688393
# PEOPLE'S PARK COMPLEX             1.0              965,000      104.0            9279      0.95205             0.964691                0.757353            0.906946       0.686878
# PEOPLE'S PARK COMPLEX             1.0              988,000      104.0            9500      0.95205             0.964691                0.757353            0.903696       0.684417
# PEOPLE'S PARK COMPLEX             1.0            1,050,000      109.0            9633      0.95205             0.964691                0.757353            0.901741       0.682936

# %%
pd.read_csv('../../datasets/updated_coordinates/outputs/combined_property_scores.csv')
# Out:
# /var/folders/g_/fmz6fbfx0l96hfjsv2764ypw0000gn/T/ipykernel_81142/784130552.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('../../datasets/updated_coordinates/outputs/combined_property_scores.csv')
#                  Project Name Transacted Price ($) Area (SQFT)  \
# 0          ONE MARINA GARDENS            1,883,403       656.6
# 1          ONE MARINA GARDENS            2,055,683       656.6
# 2       MARINA BAY RESIDENCES            1,755,000      731.95
# 3          ONE MARINA GARDENS            2,038,262      667.37
# 4       MARINA ONE RESIDENCES            4,260,000    2,249.68
# ...                       ...                  ...         ...
# 103128            THE ESTUARY              901,000       925.7
# 103129        YISHUN SAPPHIRE            1,050,000    1,388.56
# 103130  NORTH PARK RESIDENCES            1,070,000      753.48
# 103131       KANDIS RESIDENCE              975,800      796.54
# 103132       KANDIS RESIDENCE            1,019,000      731.95
#
#        Unit Price ($ PSF) Sale Date          Street Name Type of Sale  \
# 0                   2,868    Sep-25  MARINA GARDENS LANE     New Sale
# 1                   3,131    Sep-25  MARINA GARDENS LANE     New Sale
# 2                   2,398    Sep-25     MARINA BOULEVARD       Resale
# 3                   3,054    Sep-25  MARINA GARDENS LANE     New Sale
# 4                   1,894    Sep-25           MARINA WAY       Resale
# ...                   ...       ...                  ...          ...
# 103128                973    Sep-20      YISHUN AVENUE 1       Resale
# 103129                756    Sep-20       CANBERRA DRIVE       Resale
# 103130              1,420    Sep-20     YISHUN CENTRAL 1     Sub Sale
# 103131              1,225    Sep-20          KANDIS LINK     New Sale
# 103132              1,392    Sep-20          KANDIS LINK     New Sale
#
#        Type of Area Area (SQM) Unit Price ($ PSM)  ... dist_proximity_norm  \
# 0            Strata       61.0             30,875  ...            0.934106
# 1            Strata       61.0             33,700  ...            0.934106
# 2            Strata       68.0             25,809  ...            0.983777
# 3            Strata       62.0             32,875  ...            0.934106
# 4            Strata      209.0             20,383  ...            0.977327
# ...             ...        ...                ...  ...                 ...
# 103128       Strata       86.0             10,477  ...            0.280555
# 103129       Strata      129.0              8,140  ...            0.114900
# 103130       Strata       70.0             15,286  ...            0.190311
# 103131       Strata       74.0             13,186  ...            0.027225
# 103132       Strata       68.0             14,985  ...            0.027225
#
#        affordability_norm  score_property_young worth_young  \
# 0                0.589423              0.323494    0.190674
# 1                0.547887              0.323494    0.177238
# 2                0.663907              0.471217    0.312845
# 3                0.560017              0.323494    0.181162
# 4                0.743685              0.466317    0.346793
# ...                   ...                   ...         ...
# 103128           0.889332              0.175761    0.156310
# 103129           0.923692              0.201076    0.185732
# 103130           0.818626              0.261898    0.214396
# 103131           0.849502              0.045146    0.038352
# 103132           0.823051              0.045146    0.037158
#
#         score_property_family worth_family score_property_retiree  \
# 0                    0.231509     0.136457               0.208364
# 1                    0.231509     0.126841               0.208364
# 2                    0.412823     0.274076               0.427756
# 3                    0.231509     0.129649               0.208364
# 4                    0.397093     0.295312               0.411722
# ...                       ...          ...                    ...
# 103128               0.119467     0.106246               0.113898
# 103129               0.169354     0.156431               0.182668
# 103130               0.203256     0.166390               0.213714
# 103131               0.044413     0.037729               0.066522
# 103132               0.044413     0.036554               0.066522
#
#         worth_retiree  has_all_amenities has_price_data
# 0            0.122814                  1              1
# 1            0.114160                  1              1
# 2            0.283991                  1              1
# 3            0.116687                  1              1
# 4            0.306192                  1              1
# ...               ...                ...            ...
# 103128       0.101293                  1              1
# 103129       0.168729                  1              1
# 103130       0.174951                  1              1
# 103131       0.056511                  1              1
# 103132       0.054751                  1              1
#
# [103133 rows x 52 columns]

# %% [markdown]
# ## Filter per building, max 1-2 properties --- USE THIS

# %%
# clean_property_score_by_age.py
import os
import numpy as np
import pandas as pd

# ---------------- CONFIG ----------------
INPUT_CSV = "../../datasets/updated_coordinates/combined_updated.csv"
OUTPUT_DIR = "../../datasets/updated_coordinates/outputs/"
TOP_N = 10
MAX_PROPERTIES_PER_BUILDING = 2  # Limit properties per building
# ----------------------------------------

AGE_WEIGHTS = {
    'young': {
        'dist_to_cbd': 0.2376,
        'Num_MRT_With_1km': 0.1338,
        'Num_Hawker_Within_1km': 0.1019,
        'Num_Malls_Within_1km': 0.1353,
        'Num_Hospitals_Within_5km': 0.0792,
        'Num_Schools_Within_2km': 0.2080,
        'Num_Parks_Within_1km': 0.0983
    },
    'family': {
        'dist_to_cbd': 0.0709,
        'Num_MRT_With_1km': 0.1819,
        'Num_Hawker_Within_1km': 0.1149,
        'Num_Malls_Within_1km': 0.2932,
        'Num_Hospitals_Within_5km': 0.1699,
        'Num_Schools_Within_2km': 0.0867,
        'Num_Parks_Within_1km': 0.0826
    },
    'retiree': {
        'dist_to_cbd': 0.0420,
        'Num_MRT_With_1km': 0.1658,
        'Num_Hawker_Within_1km': 0.2665,
        'Num_Malls_Within_1km': 0.0969,
        'Num_Hospitals_Within_5km': 0.1971,
        'Num_Schools_Within_2km': 0.0569,
        'Num_Parks_Within_1km': 0.1748
    }
}

def ensure_dir(path):
    os.makedirs(path, exist_ok=True)

def count_semicolon_separated(x):
    """Count items in semicolon-separated string."""
    if pd.isna(x):
        return 0
    s = str(x).strip()
    if not s:
        return 0
    try:
        return max(0, int(float(s)))
    except ValueError:
        pass
    parts = [p.strip() for p in s.replace(',', ';').split(';') if p.strip()]
    return len(parts)

def robust_minmax_norm(series):
    """Min-max normalize with robust handling."""
    s = pd.to_numeric(series, errors='coerce')
    vmin, vmax = s.min(skipna=True), s.max(skipna=True)
    
    if pd.isna(vmin) or pd.isna(vmax) or vmax == vmin:
        return pd.Series(0.0, index=s.index)
    
    normalized = (s - vmin) / (vmax - vmin)
    return normalized.fillna(0.0).clip(0.0, 1.0)

def find_column(df, candidates):
    """Find first matching column from candidates."""
    for col in candidates:
        if col in df.columns:
            return col
    return None

def get_diverse_top_n(df, score_col, top_n, max_per_building=2):
    """
    Get top N properties with diversity constraint.
    Limits to max_per_building properties from each building.
    """
    result = []
    building_counts = {}
    
    # Sort by score descending
    df_sorted = df.sort_values(score_col, ascending=False).reset_index(drop=True)
    
    for idx, row in df_sorted.iterrows():
        building_name = row.get('Project Name', '')
        
        # Count how many properties from this building we've already added
        current_count = building_counts.get(building_name, 0)
        
        # Add this property if we haven't exceeded the limit
        if current_count < max_per_building:
            result.append(row)
            building_counts[building_name] = current_count + 1
        
        # Stop when we have enough properties
        if len(result) >= top_n:
            break
    
    return pd.DataFrame(result)

def prepare_and_score(input_csv, output_dir, top_n=10, max_per_building=2):
    ensure_dir(output_dir)
    
    if not os.path.exists(input_csv):
        raise FileNotFoundError(f"Input CSV not found: {input_csv}")
    
    df = pd.read_csv(input_csv)
    df = df.drop_duplicates().reset_index(drop=True)
    print(f"✓ Loaded {len(df):,} rows from {input_csv}")
    
    # ========== EXTRACT AMENITY COUNTS ==========
    amenity_mappings = {
        'Num_MRT_With_1km': [
            'Nearest MRT Stations', 'Nearest_MRT_Stations', 
            'Num MRT Within 1km', 'Num_MRT_With_1km'
        ],
        'Num_Hawker_Within_1km': [
            'Nearby Hawker Centers', 'Nearby_Hawker_Centers',
            'Num Hawker Within 1km', 'Num_Hawker_Within_1km'
        ],
        'Num_Malls_Within_1km': [
            'Shopping Malls Within Radius of 1km', 'Shopping Malls Within 1km',
            'Num Malls Within 1km', 'Num_Malls_Within_1km'
        ],
        'Num_Hospitals_Within_5km': [
            'Hospitals Within Radius of 5km', 'Hospitals Within 5km',
            'Num Hospitals Within 5km', 'Num_Hospitals_Within_5km'
        ],
        'Num_Schools_Within_2km': [
            'Schools Within Radius of 2km', 'Schools Within 2km',
            'Num Schools Within 2km', 'Num_Schools_Within_2km'
        ],
        'Num_Parks_Within_1km': [
            'Parks Within Radius of 1km', 'Parks Within 1km',
            'Num Parks Within 1km', 'Num_Parks_Within_1km'
        ]
    }
    
    for target_col, candidates in amenity_mappings.items():
        source_col = find_column(df, candidates)
        if source_col:
            if pd.api.types.is_numeric_dtype(df[source_col]):
                df[target_col] = pd.to_numeric(df[source_col], errors='coerce').fillna(0).astype(int)
            else:
                df[target_col] = df[source_col].apply(count_semicolon_separated)
        else:
            df[target_col] = 0
            print(f"⚠ Warning: No source found for {target_col}, using 0")
    
    # ========== DISTANCE TO CBD ==========
    dist_candidates = ['Dist to CBD in Km', 'Dist to CBD (Km)', 'Dist_to_CBD_km', 'dist_to_cbd']
    dist_col = find_column(df, dist_candidates)
    if dist_col:
        df['dist_to_cbd'] = pd.to_numeric(df[dist_col], errors='coerce')
    else:
        df['dist_to_cbd'] = np.nan
        print("⚠ Warning: No distance to CBD column found")
    
    # ========== POSTAL DISTRICT (if available) ==========
    if 'Postal District' in df.columns:
        df['Postal District'] = df['Postal District'].astype(str)
    else:
        df['Postal District'] = ''
    
    # ========== AREA ==========
    if 'Area (SQM)' not in df.columns and 'Area (SQFT)' in df.columns:
        df['Area (SQM)'] = pd.to_numeric(df['Area (SQFT)'], errors='coerce') * 0.092903
    elif 'Area (SQM)' not in df.columns:
        df['Area (SQM)'] = np.nan
    
    # ========== UNIT PRICE PSM (FIXED) ==========
    if 'Unit Price ($ PSM)' in df.columns:
        if pd.api.types.is_numeric_dtype(df['Unit Price ($ PSM)']):
            df['unit_price_psm'] = pd.to_numeric(df['Unit Price ($ PSM)'], errors='coerce')
        else:
            price_psm_clean = df['Unit Price ($ PSM)'].astype(str).str.replace(',', '').str.replace('$', '').str.strip()
            df['unit_price_psm'] = pd.to_numeric(price_psm_clean, errors='coerce')
    elif 'Unit Price ($ PSF)' in df.columns:
        if pd.api.types.is_numeric_dtype(df['Unit Price ($ PSF)']):
            df['unit_price_psm'] = pd.to_numeric(df['Unit Price ($ PSF)'], errors='coerce') * 10.7639
        else:
            price_psf_clean = df['Unit Price ($ PSF)'].astype(str).str.replace(',', '').str.replace('$', '').str.strip()
            df['unit_price_psm'] = pd.to_numeric(price_psf_clean, errors='coerce') * 10.7639
    else:
        price_candidates = ['Transacted Price ($)', 'Transacted Price', 'Price ($)', 'Price']
        price_col = find_column(df, price_candidates)
        
        if price_col is not None:
            price_clean = df[price_col].astype(str).str.replace(',', '').str.replace('$', '').str.strip()
            price_clean = pd.to_numeric(price_clean, errors='coerce')
            
            area_clean = pd.to_numeric(df['Area (SQM)'], errors='coerce')
            
            df['unit_price_psm'] = price_clean / area_clean.replace(0, np.nan)
        else:
            df['unit_price_psm'] = np.nan
            print("⚠ Warning: No price column found for unit_price_psm calculation")

    df['unit_price_psm'] = df['unit_price_psm'].replace([np.inf, -np.inf], np.nan)

    valid_prices = df['unit_price_psm'].notna().sum()
    print(f"✓ Valid unit_price_psm values: {valid_prices:,} / {len(df):,}")
    
    # ========== NORMALIZE FEATURES ==========
    print("\n✓ Normalizing features...")
    
    amenity_cols = [
        'Num_MRT_With_1km', 'Num_Hawker_Within_1km', 'Num_Malls_Within_1km',
        'Num_Hospitals_Within_5km', 'Num_Schools_Within_2km', 'Num_Parks_Within_1km'
    ]
    
    for col in amenity_cols:
        df[f'{col}_norm'] = robust_minmax_norm(df[col])
    
    df['dist_to_cbd_norm'] = robust_minmax_norm(df['dist_to_cbd'])
    df['dist_proximity_norm'] = 1.0 - df['dist_to_cbd_norm']
    
    if df['unit_price_psm'].notna().sum() > 0:
        df['affordability_norm'] = robust_minmax_norm(df['unit_price_psm'])
        df['affordability_norm'] = 1.0 - df['affordability_norm']
    else:
        df['affordability_norm'] = 0.5
        print("⚠ Warning: No valid unit prices found, setting affordability_norm to 0.5")
    
    # ========== COMPUTE SCORES ==========
    print("\n✓ Computing age-group scores...")
    
    feature_to_norm_col = {
        'dist_to_cbd': 'dist_proximity_norm',
        'Num_MRT_With_1km': 'Num_MRT_With_1km_norm',
        'Num_Hawker_Within_1km': 'Num_Hawker_Within_1km_norm',
        'Num_Malls_Within_1km': 'Num_Malls_Within_1km_norm',
        'Num_Hospitals_Within_5km': 'Num_Hospitals_Within_5km_norm',
        'Num_Schools_Within_2km': 'Num_Schools_Within_2km_norm',
        'Num_Parks_Within_1km': 'Num_Parks_Within_1km_norm'
    }
    
    for age_group, weights in AGE_WEIGHTS.items():
        amenity_score = np.zeros(len(df))
        
        for feature, weight in weights.items():
            norm_col = feature_to_norm_col.get(feature)
            if norm_col and norm_col in df.columns:
                amenity_score += weight * df[norm_col].values
        
        df[f'score_property_{age_group}'] = amenity_score
        df[f'worth_{age_group}'] = amenity_score * df['affordability_norm']
    
    # ========== DATA QUALITY FLAGS ==========
    df['has_all_amenities'] = (
        (df['Num_MRT_With_1km'] + df['Num_Hawker_Within_1km'] + 
         df['Num_Malls_Within_1km'] + df['Num_Hospitals_Within_5km'] + 
         df['Num_Schools_Within_2km'] + df['Num_Parks_Within_1km']) > 0
    ).astype(int)
    
    df['has_price_data'] = df['unit_price_psm'].notna().astype(int)
    
    # ========== SAVE RESULTS ==========
    combined_out = os.path.join(output_dir, "combined_property_scores_filtered.csv")
    df.to_csv(combined_out, index=False)
    print(f"\nSaved combined property-level CSV: {combined_out}")
    
    # ========== SAVE TOP N PER AGE GROUP WITH DIVERSITY ==========
    for age_group in AGE_WEIGHTS.keys():
        display_cols = [
            'Project Name', 'Postal District', 'Transacted Price ($)', 'Area (SQM)', 'unit_price_psm',
            'dist_to_cbd', 'dist_proximity_norm', f'score_property_{age_group}', 
            'affordability_norm', f'worth_{age_group}'
        ]
        display_cols = [c for c in display_cols if c in df.columns]
        
        # Filter valid properties
        valid_df = df[df['has_all_amenities'] == 1].copy()
        
        # Get top N with diversity constraint
        top_df = get_diverse_top_n(
            valid_df, 
            f'worth_{age_group}', 
            top_n, 
            max_per_building
        )[display_cols]
        
        out_file = os.path.join(output_dir, f"top{top_n}_{age_group}.csv")
        top_df.to_csv(out_file, index=False)
        
        print(f"\nTop {top_n} properties for '{age_group}' (max {max_per_building} per building):")
        print(top_df.to_string(index=False))
    
    return top_df, df

# ========== EXECUTE ==========
if __name__ == "__main__":
    df_top, df_result = prepare_and_score(
        INPUT_CSV, 
        OUTPUT_DIR, 
        top_n=TOP_N,
        max_per_building=MAX_PROPERTIES_PER_BUILDING
    )
# Out:
# /var/folders/g_/fmz6fbfx0l96hfjsv2764ypw0000gn/T/ipykernel_81142/1727967180.py:112: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_csv)
# ✓ Loaded 103,133 rows from ../../datasets/updated_coordinates/combined_updated.csv
# ✓ Valid unit_price_psm values: 103,133 / 103,133
#
# ✓ Normalizing features...
#
# ✓ Computing age-group scores...
#
# Saved combined property-level CSV: ../../datasets/updated_coordinates/outputs/combined_property_scores_filtered.csv
#
# Top 10 properties for 'young' (max 2 per building):
#          Project Name Postal District Transacted Price ($) Area (SQM)  unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_young  affordability_norm  worth_young
# PEOPLE'S PARK COMPLEX             1.0              700,000      104.0            6731     0.952050             0.964691              0.648601            0.944409     0.612545
# PEOPLE'S PARK COMPLEX             1.0            1,138,000      149.0            7638     0.952050             0.964691              0.648601            0.931073     0.603895
#         WATERLOO VIEW             7.0            1,600,000        165            9697     1.973531             0.912326              0.639292            0.900800     0.575874
#  PEOPLE'S PARK CENTRE             1.0            1,750,000      217.0            8065     0.839154             0.970479              0.620748            0.924795     0.574065
#  PEOPLE'S PARK CENTRE             1.0            1,350,000      158.0            8544     0.839154             0.970479              0.620748            0.917752     0.569693
#         WATERLOO VIEW             7.0            1,820,000        165           11030     1.973531             0.912326              0.639292            0.881201     0.563345
#         HONG BUILDING             8.0            1,422,850      127.0           11204     1.795329             0.921461              0.630463            0.878643     0.553952
#        SUNSHINE PLAZA             7.0            1,448,800        121           11974     1.918217             0.915161              0.620107            0.867321     0.537832
#        SUNSHINE PLAZA             7.0            1,550,000        125           12400     1.918217             0.915161              0.620107            0.861058     0.533948
#                   JIA             9.0            3,100,000      299.0           10368     2.184583             0.901506              0.597050            0.890934     0.531932
#
# Top 10 properties for 'family' (max 2 per building):
#          Project Name Postal District Transacted Price ($) Area (SQM)  unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_family  affordability_norm  worth_family
#         WATERLOO VIEW             7.0            1,600,000        165            9697     1.973531             0.912326               0.681452            0.900800      0.613852
#         HONG BUILDING             8.0            1,422,850      127.0           11204     1.795329             0.921461               0.692715            0.878643      0.608649
#         WATERLOO VIEW             7.0            1,820,000        165           11030     1.973531             0.912326               0.681452            0.881201      0.600496
# PEOPLE'S PARK COMPLEX             1.0              700,000      104.0            6731     0.952050             0.964691               0.605874            0.944409      0.572192
#        SUNSHINE PLAZA             7.0            1,448,800        121           11974     1.918217             0.915161               0.651859            0.867321      0.565371
# PEOPLE'S PARK COMPLEX             1.0            1,138,000      149.0            7638     0.952050             0.964691               0.605874            0.931073      0.564113
#        SUNSHINE PLAZA             7.0            1,550,000        125           12400     1.918217             0.915161               0.651859            0.861058      0.561288
#                   JIA             9.0            3,100,000      299.0           10368     2.184583             0.901506               0.618393            0.890934      0.550948
#         THE BENCOOLEN             7.0            1,587,500        118           13453     2.080129             0.906861               0.648502            0.845576      0.548358
#         THE BENCOOLEN             7.0            1,200,000         86           13953     2.080129             0.906861               0.648502            0.838224      0.543590
#
# Top 10 properties for 'retiree' (max 2 per building):
#          Project Name Postal District Transacted Price ($) Area (SQM)  unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_retiree  affordability_norm  worth_retiree
# PEOPLE'S PARK COMPLEX             1.0              700,000      104.0            6731     0.952050             0.964691                0.757353            0.944409       0.715251
# PEOPLE'S PARK COMPLEX             1.0            1,138,000      149.0            7638     0.952050             0.964691                0.757353            0.931073       0.705151
#  PEOPLE'S PARK CENTRE             1.0            1,750,000      217.0            8065     0.839154             0.970479                0.710544            0.924795       0.657108
#  PEOPLE'S PARK CENTRE             1.0            1,350,000      158.0            8544     0.839154             0.970479                0.710544            0.917752       0.652104
#             THE CLIFT             1.0            1,220,000       71.0           17183     0.570359             0.984259                0.724045            0.790734       0.572527
#         WATERLOO VIEW             7.0            1,600,000        165            9697     1.973531             0.912326                0.629044            0.900800       0.566643
#             THE CLIFT             1.0            1,400,000       77.0           18182     0.570359             0.984259                0.724045            0.776046       0.561892
#  THE RIVERSIDE PIAZZA             1.0            1,600,000       94.0           17021     0.983041             0.963103                0.706309            0.793116       0.560185
#  THE RIVERSIDE PIAZZA             1.0            1,610,000       94.0           17128     0.983041             0.963103                0.706309            0.791543       0.559074
#           ONE SHENTON             1.0            1,553,500      111.0           13995     0.412718             0.992340                0.665826            0.837607       0.557700

# %%
young_top_df = pd.read_csv('../../datasets/updated_coordinates/outputs/top10_young.csv')
family_top_df = pd.read_csv('../../datasets/updated_coordinates/outputs/top10_family.csv')
retiree_top_df = pd.read_csv('../../datasets/updated_coordinates/outputs/top10_retiree.csv')

# %%
young_top_df
# Out:
#             Project Name  Postal District Transacted Price ($)  Area (SQM)  \
# 0  PEOPLE'S PARK COMPLEX              1.0              700,000       104.0
# 1  PEOPLE'S PARK COMPLEX              1.0            1,138,000       149.0
# 2          WATERLOO VIEW              7.0            1,600,000       165.0
# 3   PEOPLE'S PARK CENTRE              1.0            1,750,000       217.0
# 4   PEOPLE'S PARK CENTRE              1.0            1,350,000       158.0
# 5          WATERLOO VIEW              7.0            1,820,000       165.0
# 6          HONG BUILDING              8.0            1,422,850       127.0
# 7         SUNSHINE PLAZA              7.0            1,448,800       121.0
# 8         SUNSHINE PLAZA              7.0            1,550,000       125.0
# 9                    JIA              9.0            3,100,000       299.0
#
#    unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_young  \
# 0            6731     0.952050             0.964691              0.648601
# 1            7638     0.952050             0.964691              0.648601
# 2            9697     1.973531             0.912326              0.639292
# 3            8065     0.839154             0.970479              0.620748
# 4            8544     0.839154             0.970479              0.620748
# 5           11030     1.973531             0.912326              0.639292
# 6           11204     1.795329             0.921461              0.630463
# 7           11974     1.918217             0.915161              0.620107
# 8           12400     1.918217             0.915161              0.620107
# 9           10368     2.184583             0.901506              0.597050
#
#    affordability_norm  worth_young
# 0            0.944409     0.612545
# 1            0.931073     0.603895
# 2            0.900800     0.575874
# 3            0.924795     0.574065
# 4            0.917752     0.569693
# 5            0.881201     0.563345
# 6            0.878643     0.553952
# 7            0.867321     0.537832
# 8            0.861058     0.533948
# 9            0.890934     0.531932

# %%
family_top_df
# Out:
#             Project Name  Postal District Transacted Price ($)  Area (SQM)  \
# 0          WATERLOO VIEW              7.0            1,600,000       165.0
# 1          HONG BUILDING              8.0            1,422,850       127.0
# 2          WATERLOO VIEW              7.0            1,820,000       165.0
# 3  PEOPLE'S PARK COMPLEX              1.0              700,000       104.0
# 4         SUNSHINE PLAZA              7.0            1,448,800       121.0
# 5  PEOPLE'S PARK COMPLEX              1.0            1,138,000       149.0
# 6         SUNSHINE PLAZA              7.0            1,550,000       125.0
# 7                    JIA              9.0            3,100,000       299.0
# 8          THE BENCOOLEN              7.0            1,587,500       118.0
# 9          THE BENCOOLEN              7.0            1,200,000        86.0
#
#    unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_family  \
# 0            9697     1.973531             0.912326               0.681452
# 1           11204     1.795329             0.921461               0.692715
# 2           11030     1.973531             0.912326               0.681452
# 3            6731     0.952050             0.964691               0.605874
# 4           11974     1.918217             0.915161               0.651859
# 5            7638     0.952050             0.964691               0.605874
# 6           12400     1.918217             0.915161               0.651859
# 7           10368     2.184583             0.901506               0.618393
# 8           13453     2.080129             0.906861               0.648502
# 9           13953     2.080129             0.906861               0.648502
#
#    affordability_norm  worth_family
# 0            0.900800      0.613852
# 1            0.878643      0.608649
# 2            0.881201      0.600496
# 3            0.944409      0.572192
# 4            0.867321      0.565371
# 5            0.931073      0.564113
# 6            0.861058      0.561288
# 7            0.890934      0.550948
# 8            0.845576      0.548358
# 9            0.838224      0.543590

# %%
retiree_top_df
# Out:
#             Project Name  Postal District Transacted Price ($)  Area (SQM)  \
# 0  PEOPLE'S PARK COMPLEX              1.0              700,000       104.0
# 1  PEOPLE'S PARK COMPLEX              1.0            1,138,000       149.0
# 2   PEOPLE'S PARK CENTRE              1.0            1,750,000       217.0
# 3   PEOPLE'S PARK CENTRE              1.0            1,350,000       158.0
# 4              THE CLIFT              1.0            1,220,000        71.0
# 5          WATERLOO VIEW              7.0            1,600,000       165.0
# 6              THE CLIFT              1.0            1,400,000        77.0
# 7   THE RIVERSIDE PIAZZA              1.0            1,600,000        94.0
# 8   THE RIVERSIDE PIAZZA              1.0            1,610,000        94.0
# 9            ONE SHENTON              1.0            1,553,500       111.0
#
#    unit_price_psm  dist_to_cbd  dist_proximity_norm  score_property_retiree  \
# 0            6731     0.952050             0.964691                0.757353
# 1            7638     0.952050             0.964691                0.757353
# 2            8065     0.839154             0.970479                0.710544
# 3            8544     0.839154             0.970479                0.710544
# 4           17183     0.570359             0.984259                0.724045
# 5            9697     1.973531             0.912326                0.629044
# 6           18182     0.570359             0.984259                0.724045
# 7           17021     0.983041             0.963103                0.706309
# 8           17128     0.983041             0.963103                0.706309
# 9           13995     0.412718             0.992340                0.665826
#
#    affordability_norm  worth_retiree
# 0            0.944409       0.715251
# 1            0.931073       0.705151
# 2            0.924795       0.657108
# 3            0.917752       0.652104
# 4            0.790734       0.572527
# 5            0.900800       0.566643
# 6            0.776046       0.561892
# 7            0.793116       0.560185
# 8            0.791543       0.559074
# 9            0.837607       0.557700

# %%
df = pd.read_csv('../../datasets/updated_coordinates/outputs/combined_property_scores_filtered.csv')
df
# Out:
# /var/folders/g_/fmz6fbfx0l96hfjsv2764ypw0000gn/T/ipykernel_81142/4199334374.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../datasets/updated_coordinates/outputs/combined_property_scores_filtered.csv')
#                  Project Name Transacted Price ($) Area (SQFT)  \
# 0          ONE MARINA GARDENS            1,883,403       656.6
# 1          ONE MARINA GARDENS            2,055,683       656.6
# 2       MARINA BAY RESIDENCES            1,755,000      731.95
# 3          ONE MARINA GARDENS            2,038,262      667.37
# 4       MARINA ONE RESIDENCES            4,260,000    2,249.68
# ...                       ...                  ...         ...
# 103128            THE ESTUARY              901,000       925.7
# 103129        YISHUN SAPPHIRE            1,050,000    1,388.56
# 103130  NORTH PARK RESIDENCES            1,070,000      753.48
# 103131       KANDIS RESIDENCE              975,800      796.54
# 103132       KANDIS RESIDENCE            1,019,000      731.95
#
#        Unit Price ($ PSF) Sale Date          Street Name Type of Sale  \
# 0                   2,868    Sep-25  MARINA GARDENS LANE     New Sale
# 1                   3,131    Sep-25  MARINA GARDENS LANE     New Sale
# 2                   2,398    Sep-25     MARINA BOULEVARD       Resale
# 3                   3,054    Sep-25  MARINA GARDENS LANE     New Sale
# 4                   1,894    Sep-25           MARINA WAY       Resale
# ...                   ...       ...                  ...          ...
# 103128                973    Sep-20      YISHUN AVENUE 1       Resale
# 103129                756    Sep-20       CANBERRA DRIVE       Resale
# 103130              1,420    Sep-20     YISHUN CENTRAL 1     Sub Sale
# 103131              1,225    Sep-20          KANDIS LINK     New Sale
# 103132              1,392    Sep-20          KANDIS LINK     New Sale
#
#        Type of Area Area (SQM) Unit Price ($ PSM)  ... dist_proximity_norm  \
# 0            Strata       61.0             30,875  ...            0.934106
# 1            Strata       61.0             33,700  ...            0.934106
# 2            Strata       68.0             25,809  ...            0.983777
# 3            Strata       62.0             32,875  ...            0.934106
# 4            Strata      209.0             20,383  ...            0.977327
# ...             ...        ...                ...  ...                 ...
# 103128       Strata       86.0             10,477  ...            0.280555
# 103129       Strata      129.0              8,140  ...            0.114900
# 103130       Strata       70.0             15,286  ...            0.190311
# 103131       Strata       74.0             13,186  ...            0.027225
# 103132       Strata       68.0             14,985  ...            0.027225
#
#        affordability_norm  score_property_young worth_young  \
# 0                0.589423              0.323494    0.190674
# 1                0.547887              0.323494    0.177238
# 2                0.663907              0.471217    0.312845
# 3                0.560017              0.323494    0.181162
# 4                0.743685              0.466317    0.346793
# ...                   ...                   ...         ...
# 103128           0.889332              0.175761    0.156310
# 103129           0.923692              0.201076    0.185732
# 103130           0.818626              0.261898    0.214396
# 103131           0.849502              0.045146    0.038352
# 103132           0.823051              0.045146    0.037158
#
#         score_property_family worth_family score_property_retiree  \
# 0                    0.231509     0.136457               0.208364
# 1                    0.231509     0.126841               0.208364
# 2                    0.412823     0.274076               0.427756
# 3                    0.231509     0.129649               0.208364
# 4                    0.397093     0.295312               0.411722
# ...                       ...          ...                    ...
# 103128               0.119467     0.106246               0.113898
# 103129               0.169354     0.156431               0.182668
# 103130               0.203256     0.166390               0.213714
# 103131               0.044413     0.037729               0.066522
# 103132               0.044413     0.036554               0.066522
#
#         worth_retiree  has_all_amenities has_price_data
# 0            0.122814                  1              1
# 1            0.114160                  1              1
# 2            0.283991                  1              1
# 3            0.116687                  1              1
# 4            0.306192                  1              1
# ...               ...                ...            ...
# 103128       0.101293                  1              1
# 103129       0.168729                  1              1
# 103130       0.174951                  1              1
# 103131       0.056511                  1              1
# 103132       0.054751                  1              1
#
# [103133 rows x 52 columns]
