# %%
# !pip install pandas numpy geopy scikit-learn

# %%
import pandas as pd
import numpy as np
from geopy.distance import geodesic
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Clean and Convert Data

# %%
def count_items(x):
            if pd.isna(x):
                return 0
            return len(str(x).split(';'))

# %%
for district_num in range(1, 29):  
    try:  
        df = pd.read_csv(f"../datasets/updated_coordinates/district{district_num}.csv")

        # Remove commas, dollar signs, etc., and convert to numeric
        for col in ["Transacted Price ($)", "Area (SQFT)", "Unit Price ($ PSF)", "Area (SQM)", "Unit Price ($ PSM)"]:
            df[col] = df[col].replace(r'[\$,]', '', regex=True).astype(float)
            df = df.dropna(subset=["Unit Price ($ PSF)", "Area (SQFT)"])

        df = df[~df['Floor Level'].isin(['B1', 'B2', 'G', 'PH'])]
        df['Sale Date'] = pd.to_datetime(df['Sale Date'], format='%b-%y', errors='coerce')
        df['Sale Months Since Sep 2025'] = round((pd.Timestamp("2025-09-01") - df['Sale Date'] ) / pd.Timedelta(days=30))
    

        df['Num MRT Within 1km'] = df['Nearest MRT Stations'].apply(count_items)
        df['Num Hawker Within 1km'] = df['Nearby Hawker Centers'].apply(count_items)
        df['Num Malls Within 1km'] = df['Shopping Malls Within Radius of 1km'].apply(count_items)
        df['Num Hospitals Within 5km'] = df['Hospitals Within Radius of 5km'].apply(count_items)
        df['Num Schools Within 2km'] = df['Schools Within Radius of 2km'].apply(count_items)
        df['Num Parks Within 1km'] = df['Parks Within Radius of 1km'].apply(count_items)

        df.drop(columns=['Nett Price($)', 'Street Name', 'Nearest MRT Stations', 'Nearby Hawker Centers', 'Shopping Malls Within Radius of 1km', 'Hospitals Within Radius of 5km', 'Schools Within Radius of 2km', 'Parks Within Radius of 1km', 'Number of Units'], inplace=True)

        df.to_csv(f"../datasets/cleaned_data/district{district_num}_cleaned.csv", index=False)

    except Exception as e:
        print(f"Error processing district {district_num}: {str(e)}")
        continue
# Out:
# Error processing district 24: [Errno 2] No such file or directory: '../datasets/updated_coordinates/district24.csv'

# %%
df
# Out:
#              Project Name  Transacted Price ($)  Area (SQFT)  \
# 0              THE WARREN             1220000.0      1044.11
# 1               MERALODGE             2358000.0      1636.13
# 2            THE SKYWOODS             1680000.0      1011.82
# 3                THE MYST             1595000.0       678.13
# 4             THE TENNERY              825000.0       613.55
# ...                   ...                   ...          ...
# 5865  FORESQUE RESIDENCES             1420000.0      1184.04
# 5866        HILLVIEW PARK             1388000.0      1227.10
# 5867       REGENT HEIGHTS             1005000.0      1496.20
# 5868          PARK NATURA             1730000.0      1646.89
# 5869          PARK NATURA             2630000.0      2508.01
#
#       Unit Price ($ PSF)  Sale Date Type of Sale Type of Area  Area (SQM)  \
# 0                 1168.0 2025-09-01       Resale       Strata        97.0
# 1                 1441.0 2025-09-01       Resale       Strata       152.0
# ...

# %% [markdown]
# ## Encode

# %%
def floor_level_to_num(floor_str):
    """
    Convert floor level string to numerical category
    B1-B5: 0 (Basement)
    01-05: 1
    06-10: 2
    11-15: 3
    16-20: 4
    21-25: 5
    26-30: 6
    31-35: 7
    36-40: 8
    41-45: 9
    46-50: 10
    etc.
    """
    if pd.isna(floor_str):
        return np.nan
    
    floor_str = str(floor_str).strip().upper()
    
    # Handle basement floors
    if 'B' in floor_str:
        return 0
    
    # Extract the starting floor number
    try:
        # Handle formats like "01 to 05", "01-05", etc.
        start_floor = int(floor_str.split()[0].split('-')[0])
        
        # Calculate category: floors 1-5 = 1, 6-10 = 2, etc.
        category = ((start_floor - 1) // 5) + 1
        return category
    except:
        return np.nan

def encode_type_of_sale(value):
    """
    Convert Type of Sale to numerical
    New Sale: 0
    Resale: 1
    """
    if pd.isna(value):
        return np.nan
    value_lower = str(value).lower()
    if 'new' in value_lower:
        return 0
    elif 'resale' in value_lower:
        return 1
    else:
        return np.nan

def encode_property_type(value):
    """
    Convert Property Type to numerical
    Apartment: 0
    Condominium: 1
    """
    if pd.isna(value):
        return np.nan
    value_lower = str(value).lower()
    if 'apartment' in value_lower:
        return 0
    elif 'condominium' in value_lower:
        return 1
    else:
        return np.nan

def encode_market_segment(value):
    """
    Convert Market Segment to numerical
    This depends on your specific categories
    You may need to adjust based on actual values
    """
    if pd.isna(value):
        return np.nan
    
    value_lower = str(value).lower()
    
    # Define your mapping based on actual categories in your data
    segment_mapping = {
        'ccr': 0,  # Core Central Region
        'core central region': 0,
        'rcr': 1,  # Rest of Central Region
        'rest of central region': 1,
        'ocr': 2,  # Outside Central Region
        'outside central region': 2
    }
    
    for key, num in segment_mapping.items():
        if key in value_lower:
            return num
    
    return np.nan

# %%
# Main processing loop
for district_num in range(1, 29):
    try:
        print(f"Processing district {district_num}...")
        cleaned_df = pd.read_csv(f"../datasets/cleaned_data/district{district_num}_cleaned.csv")
        
        # Create a copy to work with
        encoded_df = cleaned_df.copy()
        
        # ===================================================================
        # 1. ENCODE FLOOR LEVEL
        # ===================================================================
        if 'Floor Level' in encoded_df.columns:
            encoded_df['Floor_Level_Category'] = encoded_df['Floor Level'].apply(floor_level_to_num)
            # Optionally drop the original Floor Level column
            # encoded_df = encoded_df.drop('Floor Level', axis=1)
        
        # ===================================================================
        # 2. ENCODE TYPE OF SALE
        # ===================================================================
        if 'Type of Sale' in encoded_df.columns:
            encoded_df['Type_of_Sale_Encoded'] = encoded_df['Type of Sale'].apply(encode_type_of_sale)
            # Drop one-hot encoded columns if they exist
            type_sale_cols = [col for col in encoded_df.columns if col.startswith('Type of Sale_')]
            encoded_df = encoded_df.drop(type_sale_cols, axis=1)
            # Optionally drop original column
            # encoded_df = encoded_df.drop('Type of Sale', axis=1)
        
        # ===================================================================
        # 3. ENCODE PROPERTY TYPE
        # ===================================================================
        if 'Property Type' in encoded_df.columns:
            encoded_df['Property_Type_Encoded'] = encoded_df['Property Type'].apply(encode_property_type)
            # Drop one-hot encoded columns if they exist
            property_type_cols = [col for col in encoded_df.columns if col.startswith('Property Type_')]
            encoded_df = encoded_df.drop(property_type_cols, axis=1)
            # Optionally drop original column
            # encoded_df = encoded_df.drop('Property Type', axis=1)
        
        
        # ===================================================================
        # 5. ENCODE MARKET SEGMENT
        # ===================================================================
        if 'Market Segment' in encoded_df.columns:
            encoded_df['Market_Segment_Encoded'] = encoded_df['Market Segment'].apply(encode_market_segment)
            # Drop one-hot encoded columns if they exist
            market_segment_cols = [col for col in encoded_df.columns if col.startswith('Market Segment_')]
            encoded_df = encoded_df.drop(market_segment_cols, axis=1)
            # Optionally drop original column
            # encoded_df = encoded_df.drop('Market Segment', axis=1)
        
        # ===================================================================
        # 7. HANDLE TYPE OF AREA (if it's categorical)
        # ===================================================================
        if 'Type of Area' in encoded_df.columns:
            # Check if it needs encoding
            unique_values = encoded_df['Type of Area'].unique()
            print(f"  Type of Area unique values: {unique_values}")
            
            # If it's categorical like "Strata", "Land", etc., encode it
            area_type_mapping = {
                'strata': 0,
                'land': 1,
                # Add more as needed
            }
            encoded_df['Type_of_Area_Encoded'] = encoded_df['Type of Area'].apply(
                lambda x: area_type_mapping.get(str(x).lower(), np.nan) if pd.notna(x) else np.nan
            )
        
        # ===================================================================
        # 8. SAVE PROCESSED DATA
        # ===================================================================
        # Save the encoded dataframe
        encoded_df.to_csv(f"../datasets/cleaned_data/district{district_num}_cleaned.csv", index=False)
        
        print(f"✓ Successfully processed district {district_num}")
        print(f"  Original columns: {len(cleaned_df.columns)}")
        print(f"  New columns: {len(encoded_df.columns)}")
        print(f"  Added encodings: {len(encoded_df.columns) - len(cleaned_df.columns)}")
        print()
    
    except FileNotFoundError:
        print(f"⚠ File not found for district {district_num}")
        continue
    except Exception as e:
        print(f"✗ Error processing district {district_num}: {str(e)}")
        import traceback
        traceback.print_exc()
        continue

print("="*80)
print("ENCODING COMPLETE!")
print("="*80)
# Out:
# Processing district 1...
#   Type of Area unique values: ['Strata']
# ✓ Successfully processed district 1
#   Original columns: 25
#   New columns: 30
#   Added encodings: 5
#
# Processing district 2...
#   Type of Area unique values: ['Strata']
# ✓ Successfully processed district 2
#   Original columns: 25
#   New columns: 30
#   Added encodings: 5
#
# Processing district 3...
#   Type of Area unique values: ['Strata']
# ✓ Successfully processed district 3
#   Original columns: 25
#   New columns: 30
#   Added encodings: 5
#
# Processing district 4...
#   Type of Area unique values: ['Strata']
# ✓ Successfully processed district 4
#   Original columns: 25
#   New columns: 30
#   Added encodings: 5
#
# Processing district 5...
#   Type of Area unique values: ['Strata']
# ✓ Successfully processed district 5
#   Original columns: 25
#   New columns: 30
#   Added encodings: 5
#
# Processing district 6...
#   Type of Area unique values: ['Strata']
# ✓ Successfully processed district 6
# ...

# %%
for district_num in range(1, 29):
    try:
        encoded_df = pd.read_csv(f"../datasets/cleaned_data/district{district_num}_cleaned.csv")
        
        # List of columns to drop if they exist
        columns_to_drop = [
            'Postal District',
            'Property Type',
            'Tenure',
            'Market Segment',
            'Floor Level',
            'Type of Sale',
            'Type of Area',
            'Postal_District_Encoded'
        ]
        
        # Find which columns actually exist in the dataframe
        existing_columns_to_drop = [col for col in columns_to_drop if col in encoded_df.columns]
        
        # Drop the existing columns
        if existing_columns_to_drop:
            encoded_df.drop(columns=existing_columns_to_drop, inplace=True)
            print(f"District {district_num}: Dropped columns {existing_columns_to_drop}")
        else:
            print(f"District {district_num}: No columns to drop")
        
        # Save the modified dataframe
        encoded_df.to_csv(f"../datasets/cleaned_data/district{district_num}_cleaned.csv", index=False)
        
    except FileNotFoundError:
        print(f"File not found for district {district_num}")
        continue
    except Exception as e:
        print(f"Error processing district {district_num}: {str(e)}")
        continue

print("Column dropping complete!")
# Out:
# District 1: Dropped columns ['Property Type', 'Tenure', 'Market Segment', 'Floor Level', 'Type of Sale', 'Type of Area', 'Postal_District_Encoded']
# District 2: Dropped columns ['Property Type', 'Tenure', 'Market Segment', 'Floor Level', 'Type of Sale', 'Type of Area', 'Postal_District_Encoded']
# District 3: Dropped columns ['Property Type', 'Tenure', 'Market Segment', 'Floor Level', 'Type of Sale', 'Type of Area', 'Postal_District_Encoded']
# District 4: Dropped columns ['Property Type', 'Tenure', 'Market Segment', 'Floor Level', 'Type of Sale', 'Type of Area', 'Postal_District_Encoded']
# District 5: Dropped columns ['Property Type', 'Tenure', 'Market Segment', 'Floor Level', 'Type of Sale', 'Type of Area', 'Postal_District_Encoded']
# District 6: Dropped columns ['Property Type', 'Tenure', 'Market Segment', 'Floor Level', 'Type of Sale', 'Type of Area', 'Postal_District_Encoded']
# ...

# %%
encoded_df.head()
# Out:
#    Project Name  Transacted Price ($)  Area (SQFT)  Unit Price ($ PSF)  \
# 0    THE WARREN             1220000.0      1044.11              1168.0
# 1     MERALODGE             2358000.0      1636.13              1441.0
# 2  THE SKYWOODS             1680000.0      1011.82              1660.0
# 3      THE MYST             1595000.0       678.13              2352.0
# 4   THE TENNERY              825000.0       613.55              1345.0
#
#     Sale Date Type of Sale Type of Area  Area (SQM)  Unit Price ($ PSM)  \
# 0  2025-09-01       Resale       Strata        97.0             12577.0
# 1  2025-09-01       Resale       Strata       152.0             15513.0
# 2  2025-09-01       Resale       Strata        94.0             17872.0
# 3  2025-09-01     New Sale       Strata        63.0             25317.0
# 4  2025-09-01       Resale       Strata        57.0             14474.0
#
#   Property Type  ... Num Hawker Within 1km  Num Malls Within 1km  \
# ...

# %%
encoded_df.columns.tolist()
# Out:
# ['Project Name',
#  'Transacted Price ($)',
#  'Area (SQFT)',
#  'Unit Price ($ PSF)',
#  'Sale Date',
#  'Type of Sale',
#  'Type of Area',
#  'Area (SQM)',
#  'Unit Price ($ PSM)',
#  'Property Type',
#  'Tenure',
#  'Postal District',
#  'Market Segment',
#  'Floor Level',
#  'Latitude',
#  'Longitude',
#  'Full Address',
#  'Dist to CBD in Km',
#  'Sale Months Since Sep 2025',
#  'Num MRT Within 1km',
#  'Num Hawker Within 1km',
#  'Num Malls Within 1km',
#  'Num Hospitals Within 5km',
#  'Num Schools Within 2km',
#  'Num Parks Within 1km',
#  'Floor_Level_Category',
#  'Type_of_Sale_Encoded',
#  'Property_Type_Encoded',
#  'Market_Segment_Encoded',
#  'Type_of_Area_Encoded']

# %% [markdown]
# ## Z-Score Normalization

# %%
for district_num in range(1, 29):
    try:
        normalized_df = pd.read_csv(f"../datasets/cleaned_data/district{district_num}_cleaned.csv")

        num_cols = ['Transacted Price ($)',
                    'Area (SQFT)',
                    'Unit Price ($ PSF)',
                    'Postal District',
                    'Dist to CBD in Km',
                    'Sale Months Since Sep 2025',
                    'Num MRT Within 1km',
                    'Num Hawker Within 1km',
                    'Num Malls Within 1km',
                    'Num Hospitals Within 5km',
                    'Num Schools Within 2km',
                    'Num Parks Within 1km',
                    'Floor_Level_Category',
                    'Type_of_Sale_Encoded',
                    'Property_Type_Encoded',
                    'Market_Segment_Encoded',
                    'Type_of_Area_Encoded']

        scaler = StandardScaler()
        normalized_df[num_cols] = scaler.fit_transform(normalized_df[num_cols])
        normalized_df = normalized_df[num_cols]

        normalized_df.to_csv(f"../datasets/normalized_data/district{district_num}_normalized.csv")
    
    except Exception as e:
        print(f"Error processing district {district_num}: {str(e)}")
        continue
# Out:
# Error processing district 24: [Errno 2] No such file or directory: '../datasets/cleaned_data/district24_cleaned.csv'

# %%
normalized_df.head()
# Out:
#    Transacted Price ($)  Area (SQFT)  Unit Price ($ PSF)  Postal District  \
# 0             -0.346776     0.175782           -0.765668              0.0
# 1              1.892528     1.835504           -0.098898              0.0
# 2              0.558391     0.085257            0.435984              0.0
# 3              0.391132    -0.850240            2.126113              0.0
# 4             -1.124038    -1.031289           -0.333366              0.0
#
#    Dist to CBD in Km  Sale Months Since Sep 2025  Num MRT Within 1km  \
# 0           2.382284                   -1.874755            0.187207
# 1          -0.634930                   -1.874755           -1.238095
# 2          -0.607620                   -1.874755           -0.287893
# 3           0.306465                   -1.874755            1.612510
# 4           0.927459                   -1.874755            2.087610
#
#    Num Hawker Within 1km  Num Malls Within 1km  Num Hospitals Within 5km  \
# ...

# %%
normalized_df.columns.tolist()
# Out:
# ['Transacted Price ($)',
#  'Area (SQFT)',
#  'Unit Price ($ PSF)',
#  'Postal District',
#  'Dist to CBD in Km',
#  'Sale Months Since Sep 2025',
#  'Num MRT Within 1km',
#  'Num Hawker Within 1km',
#  'Num Malls Within 1km',
#  'Num Hospitals Within 5km',
#  'Num Schools Within 2km',
#  'Num Parks Within 1km',
#  'Floor_Level_Category',
#  'Type_of_Sale_Encoded',
#  'Property_Type_Encoded',
#  'Market_Segment_Encoded',
#  'Type_of_Area_Encoded']

# %% [markdown]
# ## Feature Engineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import pearsonr, spearmanr
import warnings
warnings.filterwarnings('ignore')

# ============================================================================
# LOAD ALL DISTRICT DATA
# ============================================================================
print("="*80)
print("LOADING NORMALIZED DATA FROM ALL DISTRICTS")
print("="*80)

all_districts = []
for district_num in range(1, 29):
    try:
        df_district = pd.read_csv(f"../datasets/normalized_data/district{district_num}_normalized.csv")
        df_district['District'] = district_num
        all_districts.append(df_district)
        print(f"✓ District {district_num}: {len(df_district)} samples loaded")
    except FileNotFoundError:
        print(f"✗ District {district_num}: File not found")
        continue
    except Exception as e:
        print(f"✗ District {district_num}: Error - {str(e)}")
        continue

# Combine all districts
df = pd.concat(all_districts, ignore_index=True)
print(f"\n{'='*80}")
print(f"TOTAL DATASET: {len(df):,} samples from {len(all_districts)} districts")
print(f"{'='*80}\n")

# ============================================================================
# FEATURE DESCRIPTIONS
# ============================================================================
feature_descriptions = {
    'Transacted Price ($)': 'Final sale price of the property (normalized)',
    'Area (SQFT)': 'Total floor area in square feet (normalized)',
    'Unit Price ($ PSF)': 'Price per square foot (normalized)',
    'Postal District': 'Singapore postal district (0-28, normalized)',
    'Dist to CBD in Km': 'Distance to Central Business District in kilometers (normalized)',
    'Sale Months Since Sep 2025': 'Number of months since September 2025 (normalized)',
    'Num MRT Within 1km': 'Number of MRT stations within 1km radius (normalized)',
    'Num Hawker Within 1km': 'Number of hawker centers within 1km radius (normalized)',
    'Num Malls Within 1km': 'Number of shopping malls within 1km radius (normalized)',
    'Num Hospitals Within 5km': 'Number of hospitals within 5km radius (normalized)',
    'Num Schools Within 2km': 'Number of schools within 2km radius (normalized)',
    'Num Parks Within 1km': 'Number of parks within 1km radius (normalized)',
    'Floor_Level_Category': 'Floor level category (encoded and normalized)',
    'Type_of_Sale_Encoded': 'Type of sale (e.g., New Sale, Resale - encoded)',
    'Property_Type_Encoded': 'Property type (e.g., Condo, Apartment - encoded)',
    'Market_Segment_Encoded': 'Market segment (e.g., RCR, CCR, OCR - encoded)',
    'Type_of_Area_Encoded': 'Type of area measurement (encoded)'
}

print("\n" + "="*80)
print("FEATURE DESCRIPTIONS")
print("="*80)
for feature, description in feature_descriptions.items():
    if feature in df.columns:
        print(f"{feature:30s}: {description}")

# ============================================================================
# 1. CORRELATION ANALYSIS WITH INTERPRETATIONS
# ============================================================================
print("\n" + "="*80)
print("1. CORRELATION ANALYSIS (Pearson)")
print("="*80)

# Calculate correlation with target
correlations = df.drop('District', axis=1).corr()['Transacted Price ($)'].sort_values(ascending=False)

def interpret_correlation(corr_value):
    """Interpret correlation strength and direction"""
    abs_corr = abs(corr_value)
    direction = "Positive" if corr_value > 0 else "Negative"
    
    if abs_corr >= 0.7:
        strength = "Very Strong"
    elif abs_corr >= 0.5:
        strength = "Strong"
    elif abs_corr >= 0.3:
        strength = "Moderate"
    elif abs_corr >= 0.1:
        strength = "Weak"
    else:
        strength = "Very Weak"
    
    return f"{strength} {direction}"

print("\nCorrelation with Transacted Price:")
print("-"*80)
print(f"{'Feature':<35} {'Correlation':<12} {'Interpretation':<30}")
print("-"*80)

for feature, corr in correlations.items():
    if feature != 'Transacted Price ($)':
        interpretation = interpret_correlation(corr)
        print(f"{feature:<35} {corr:>7.4f}       {interpretation}")

# Visualize correlation matrix - IMPROVED VERSION
plt.figure(figsize=(16, 12))
corr_matrix = df.drop('District', axis=1).corr()

# Create mask for upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Create heatmap
sns.heatmap(corr_matrix, 
            mask=mask,
            annot=True, 
            cmap='RdBu_r',  # Red for negative, Blue for positive
            center=0, 
            fmt='.2f', 
            square=True, 
            linewidths=0.5,
            cbar_kws={"shrink": 0.8, "label": "Correlation Coefficient"},
            vmin=-1, vmax=1)

plt.title('Correlation Matrix - Real Estate Features\n(Only showing lower triangle to reduce redundancy)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig('./outputs/correlation_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# ============================================================================
# 2. FEATURE IMPORTANCE - RANDOM FOREST
# ============================================================================
print("\n" + "="*80)
print("2. RANDOM FOREST FEATURE IMPORTANCE")
print("="*80)

X = df.drop(['Transacted Price ($)', 'District'], axis=1)
y = df['Transacted Price ($)']

# Train Random Forest
rf_model = RandomForestRegressor(
    n_estimators=200, 
    random_state=42, 
    max_depth=15,
    min_samples_split=10,
    min_samples_leaf=5,
    n_jobs=-1
)
rf_model.fit(X, y)

# Get feature importances
feature_importance_rf = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_model.feature_importances_
}).sort_values('Importance', ascending=False)

print("\nRandom Forest Feature Importance:")
print("-"*80)
print(f"{'Rank':<6} {'Feature':<35} {'Importance':<12} {'Interpretation'}")
print("-"*80)

for idx, row in feature_importance_rf.iterrows():
    rank = feature_importance_rf.index.get_loc(idx) + 1
    importance = row['Importance']
    
    if importance > 0.15:
        interpretation = "🔴 Critical"
    elif importance > 0.10:
        interpretation = "🟠 Very Important"
    elif importance > 0.05:
        interpretation = "🟡 Important"
    elif importance > 0.02:
        interpretation = "🟢 Moderate"
    else:
        interpretation = "⚪ Low"
    
    print(f"{rank:<6} {row['Feature']:<35} {importance:>7.4f}      {interpretation}")

# Visualize RF importance - IMPROVED
fig, ax = plt.subplots(figsize=(14, 10))

# Create color gradient based on importance
colors = plt.cm.RdYlGn_r(feature_importance_rf['Importance'] / feature_importance_rf['Importance'].max())

bars = ax.barh(feature_importance_rf['Feature'], feature_importance_rf['Importance'])
for bar, color in zip(bars, colors):
    bar.set_color(color)

ax.set_xlabel('Importance Score', fontsize=13, fontweight='bold')
ax.set_ylabel('Features', fontsize=13, fontweight='bold')
ax.set_title('Random Forest Feature Importance\n(Darker colors = more important)', 
             fontsize=16, fontweight='bold', pad=20)
ax.invert_yaxis()
ax.grid(axis='x', alpha=0.3, linestyle='--')

# Add value labels on bars
for i, (feature, importance) in enumerate(zip(feature_importance_rf['Feature'], 
                                                feature_importance_rf['Importance'])):
    ax.text(importance, i, f'  {importance:.4f}', 
            va='center', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.savefig('./outputs/random_forest_importance.png', dpi=300, bbox_inches='tight')
plt.show()

# ============================================================================
# 3. PERMUTATION IMPORTANCE (MORE RELIABLE)
# ============================================================================
print("\n" + "="*80)
print("3. PERMUTATION IMPORTANCE (Model-Agnostic, More Reliable)")
print("="*80)
print("Computing permutation importance (this may take a moment)...")

perm_importance = permutation_importance(
    rf_model, X, y, 
    n_repeats=30,  # More repeats for stability
    random_state=42,
    n_jobs=-1
)

feature_importance_perm = pd.DataFrame({
    'Feature': X.columns,
    'Importance': perm_importance.importances_mean,
    'Std': perm_importance.importances_std
}).sort_values('Importance', ascending=False)

print("\nPermutation Importance (Mean ± Std Dev):")
print("-"*80)
print(f"{'Rank':<6} {'Feature':<35} {'Mean':<12} {'Std Dev':<12} {'Interpretation'}")
print("-"*80)

for idx, row in feature_importance_perm.iterrows():
    rank = feature_importance_perm.index.get_loc(idx) + 1
    importance = row['Importance']
    std = row['Std']
    
    # Interpretation based on mean and consistency
    if importance > 0.05 and std < importance * 0.3:
        interpretation = "🔴 Highly Reliable & Important"
    elif importance > 0.05:
        interpretation = "🟠 Important but Variable"
    elif importance > 0.02:
        interpretation = "🟡 Moderate Impact"
    elif importance > 0:
        interpretation = "🟢 Minor Impact"
    else:
        interpretation = "⚪ Negligible Impact"
    
    print(f"{rank:<6} {row['Feature']:<35} {importance:>7.4f}      ±{std:>7.4f}     {interpretation}")

# Visualize permutation importance - IMPROVED
fig, ax = plt.subplots(figsize=(14, 10))

bars = ax.barh(feature_importance_perm['Feature'], 
               feature_importance_perm['Importance'],
               xerr=feature_importance_perm['Std'],
               capsize=5, 
               color='#3498db', 
               alpha=0.8,
               edgecolor='#2c3e50',
               linewidth=1.5)

ax.set_xlabel('Permutation Importance (Decrease in R² Score)', fontsize=13, fontweight='bold')
ax.set_ylabel('Features', fontsize=13, fontweight='bold')
ax.set_title('Permutation Feature Importance\n(Error bars show standard deviation across shuffles)', 
             fontsize=16, fontweight='bold', pad=20)
ax.invert_yaxis()
ax.grid(axis='x', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.savefig('./outputs/permutation_importance.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ...
# LOADING NORMALIZED DATA FROM ALL DISTRICTS
# ...
# ✓ District 1: 1638 samples loaded
# ✓ District 2: 1233 samples loaded
# ✓ District 3: 4888 samples loaded
# ✓ District 4: 2141 samples loaded
# ✓ District 5: 8654 samples loaded
# ✓ District 6: 712 samples loaded
# ✓ District 7: 1363 samples loaded
# ✓ District 8: 1481 samples loaded
# ✓ District 9: 5926 samples loaded
# ✓ District 10: 7127 samples loaded
# ✓ District 11: 2677 samples loaded
# ✓ District 12: 3273 samples loaded
# ✓ District 13: 2302 samples loaded
# ✓ District 14: 5244 samples loaded
# ✓ District 15: 9924 samples loaded
# ✓ District 16: 4057 samples loaded
# ✓ District 17: 2362 samples loaded
# ✓ District 18: 7126 samples loaded
# ✓ District 19: 9937 samples loaded
# ✓ District 20: 2929 samples loaded
# ✓ District 21: 5857 samples loaded
# ✓ District 22: 2303 samples loaded
# ✓ District 23: 5870 samples loaded
# ✗ District 24: File not found
# ✓ District 25: 953 samples loaded
# ✓ District 26: 4334 samples loaded
# ...

# %%
# ============================================================================
# 9. FEATURE ENGINEERING RECOMMENDATIONS
# ============================================================================
print("\n" + "="*80)
print("9. FEATURE ENGINEERING RECOMMENDATIONS")
print("="*80)

# Identify high-correlation pairs (potential for interaction terms)
corr_matrix = df.drop(['District'], axis=1).corr()
high_corr_pairs = []

for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > 0.6 and corr_matrix.columns[i] != 'Transacted Price ($)':
            high_corr_pairs.append({
                'Feature 1': corr_matrix.columns[i],
                'Feature 2': corr_matrix.columns[j],
                'Correlation': corr_matrix.iloc[i, j]
            })

print("\n📊 HIGH CORRELATION PAIRS (Potential for Interaction Terms):")
print("-"*80)
if high_corr_pairs:
    for pair in sorted(high_corr_pairs, key=lambda x: abs(x['Correlation']), reverse=True)[:10]:
        print(f"   • {pair['Feature 1']} ↔️ {pair['Feature 2']}: {pair['Correlation']:.3f}")
        print(f"     💡 Consider creating: {pair['Feature 1']} × {pair['Feature 2']}")
else:
    print("   No high correlation pairs found (threshold > 0.6)")

print("\n\n📈 RECOMMENDED NEW FEATURES:")
print("-"*80)

recommendations = [
    {
        'name': 'Amenity_Score',
        'formula': '(Num MRT + Num Hawker + Num Malls + Num Parks) / 4',
        'rationale': 'Composite score of nearby amenities'
    },
    {
        'name': 'Area_to_Price_Ratio',
        'formula': 'Area (SQFT) / Transacted Price ($)',
        'rationale': 'Efficiency metric - more area per dollar'
    },
    {
        'name': 'Location_Premium',
        'formula': 'Unit Price ($ PSF) / (Dist to CBD in Km + 1)',
        'rationale': 'Price premium adjusted for CBD distance'
    },
    {
        'name': 'Service_Density',
        'formula': 'Num Hospitals + Num Schools',
        'rationale': 'Combined healthcare and education access'
    },
    {
        'name': 'Transport_Accessibility',
        'formula': 'Num MRT Within 1km × (1 / (Dist to CBD in Km + 1))',
        'rationale': 'MRT access weighted by CBD proximity'
    }
]

for i, rec in enumerate(recommendations, 1):
    print(f"\n{i}. {rec['name']}")
    print(f"   Formula: {rec['formula']}")
    print(f"   Rationale: {rec['rationale']}")

print("\n\n🎯 FEATURE SELECTION RECOMMENDATIONS:")
print("-"*80)

# Top features to definitely keep
top_features = df.head(10)
print("\n✅ MUST KEEP (Top 10 by combined score):")
for idx, row in top_features.iterrows():
    print(f"   • {row['Feature']:<40} (Score: {row['Weighted_Score']:.4f})")

# Features to consider removing
bottom_features = df.tail(5)
print("\n\n❓ CONSIDER REMOVING (Bottom 5 by combined score):")
for idx, row in bottom_features.iterrows():
    print(f"   • {row['Feature']:<40} (Score: {row['Weighted_Score']:.4f})")

# ============================================================================
# 10. SUMMARY REPORT
# ============================================================================
print("\n" + "="*80)
print("📋 EXECUTIVE SUMMARY REPORT")
print("="*80)

print(f"\n📊 DATASET OVERVIEW:")
print(f"   • Total Samples: {len(df):,}")
print(f"   • Total Features: {len(X.columns)}")
print(f"   • Districts Covered: {df['District'].nunique()}")
print(f"   • Data Type: Normalized (StandardScaler applied)")

print(f"\n\n🏆 TOP 3 MOST IMPORTANT FEATURES:")
for idx, (_, row) in enumerate(df.head(3).iterrows(), 1):
    print(f"\n   {idx}. {row['Feature']}")
    print(f"      • Weighted Score: {row['Weighted_Score']:.4f}")
    print(f"      • Description: {feature_descriptions.get(row['Feature'], 'N/A')}")
    
    # Show which method ranked it highest
    methods = {
        'Correlation': row['Correlation_Norm'],
        'Random Forest': row['RF_Importance_Norm'],
        'Permutation': row['Perm_Importance_Norm'],
        'Linear Regression': row['LR_Coefficient_Norm'],
        'Lasso': row['Lasso_Coefficient_Norm']
    }
    best_method = max(methods, key=methods.get)
    print(f"      • Strongest in: {best_method} ({methods[best_method]:.4f})")

print(f"\n\n⚠️ LEAST IMPORTANT FEATURES (Consider Removing):")
for idx, (_, row) in enumerate(df.tail(3).iterrows(), 1):
    print(f"   {idx}. {row['Feature']:<40} (Score: {row['Weighted_Score']:.4f})")

print(f"\n\n💾 OUTPUTS SAVED:")
print("   • ./outputs/correlation_matrix.png")
print("   • ./outputs/random_forest_importance.png")
print("   • ./outputs/permutation_importance.png")
print("   • ./outputs/combined_feature_ranking.png")
print("   • ./outputs/association_matrix.png")
print("   • ./outputs/top_features_analysis.png")

print("\n" + "="*80)
print("ANALYSIS COMPLETE!")
print("="*80 + "\n")

# ============================================================================
# SAVE RESULTS TO CSV
# ============================================================================
df.to_csv('./outputs/feature_importance_analysis.csv', index=False)
print("✅ Feature importance analysis saved to: ./outputs/feature_importance_analysis.csv")
# Out:
# ...
# 9. FEATURE ENGINEERING RECOMMENDATIONS
# ...
#
# 📊 HIGH CORRELATION PAIRS (Potential for Interaction Terms):
# --------------------------------------------------------------------------------
#    • Unnamed: 0 ↔️ Sale Months Since Sep 2025: 0.727
#      💡 Consider creating: Unnamed: 0 × Sale Months Since Sep 2025
#    • Unit Price ($ PSF) ↔️ Type_of_Sale_Encoded: -0.668
#      💡 Consider creating: Unit Price ($ PSF) × Type_of_Sale_Encoded
#
#
# 📈 RECOMMENDED NEW FEATURES:
# --------------------------------------------------------------------------------
#
# 1. Amenity_Score
#    Formula: (Num MRT + Num Hawker + Num Malls + Num Parks) / 4
#    Rationale: Composite score of nearby amenities
#
# 2. Area_to_Price_Ratio
#    Formula: Area (SQFT) / Transacted Price ($)
#    Rationale: Efficiency metric - more area per dollar
#
# 3. Location_Premium
#    Formula: Unit Price ($ PSF) / (Dist to CBD in Km + 1)
#    Rationale: Price premium adjusted for CBD distance
#
# 4. Service_Density
# ...

# %% [markdown]
# ## Regression Data

# %%
X = df.drop(columns=["Unit Price ($ PSF)", "Project Name", "Full Address"])
y = df["Unit Price ($ PSF)"]
